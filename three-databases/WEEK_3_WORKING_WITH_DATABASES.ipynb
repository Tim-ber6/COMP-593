# %% [markdown]
# <a href="https://colab.research.google.com/github/Tim-ber6/COMP-593/blob/main/three-databases/WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
# myConnection.commit()
# myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-03-03 02:16:31.580040',
#   '2022-03-03 02:16:31.580047',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-13.3.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 4.8 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.3.0

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {} ||'.format( fake.name(), fake.job() ) )
# Out:
# Stephanie Yates || Production manager ||
# Kelly Oconnell || Risk analyst ||
# Daniel Fisher || Buyer, retail ||
# Sean Reyes || Financial planner ||
# Robert Collier || Editor, commissioning ||
# Kyle Cole || Special educational needs teacher ||
# Keith Lee || Manufacturing engineer ||
# Thomas Pratt || Scientist, research (physical sciences) ||
# Ashley Barrett || Public relations officer ||
# Taylor Salazar || Plant breeder/geneticist ||

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker()


for _ in range(1000):
  myPerson = (fake.name(), 
            fake.email(), 
            fake.address(), 
            fake.city(), 
            fake.state(), 
            fake.country(), 
            fake.phone_number(), 
            fake.sentence(nb_words=10),
            "1967-09-12",
            fake.random_int(min=999, max=2500),
            datetime.now(), 
            datetime.now(),
            fake.ipv4())
  myCursor.execute(addPersonQuery, myPerson)
  myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

myConnection.commit()
myConnection.close()
#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
# Out:
# Streaming output truncated to the last 5000 lines.
#   'Quickly reflect floor true TV about couple instead student manager list '
#   'development.',
#   '1967-09-12',
#   1783,
#   '2022-03-03 02:26:39.405449',
#   '2022-03-03 02:26:39.405452',
#   '221.219.114.4'),
#  (1650,
#   'Angela Strong',
#   'halematthew@example.net',
#   'USNV Wolfe\nFPO AP 90104',
#   'West Samantha',
#   'New Jersey',
#   'Northern Mariana Islands',
#   '656-120-3599x153',
#   'Represent attention second west change manager church great term protect '
#   'finish bill read.',
#   '1967-09-12',
#   2300,
#   '2022-03-03 02:26:39.406174',
#   '2022-03-03 02:26:39.406177',
#   '163.243.149.251'),
#  (1651,
#   'Spencer Martinez',
#   'vaughanchristina@example.org',
#   '08383 Cole Flats\nThomasville, SC 01535',
#   'Jessicafurt',
#   'Massachusetts',
#   'Bolivia',
#   '250-748-7176',
#   'Six have seat number short order hold decide whatever.',
#   '1967-09-12',
#   1603,
#   '2022-03-03 02:26:39.407021',
#   '2022-03-03 02:26:39.407025',
#   '157.227.130.79'),
#  (1652,
#   'Gabriela Berger',
#   'careywanda@example.org',
#   '5112 Kari Lane\nSteeleborough, GA 04725',
#   'Johnville',
#   'Ohio',
#   'Cameroon',
#   '001-789-873-8451x52863',
#   'Deal material data live dinner camera.',
#   '1967-09-12',
#   1911,
#   '2022-03-03 02:26:39.407845',
#   '2022-03-03 02:26:39.407849',
#   '98.159.10.222'),
#  (1653,
#   'Teresa Young',
#   'cindyjohnson@example.net',
#   '9331 Anthony Crescent Apt. 087\nOwensview, NV 23682',
#   'Jenniferton',
#   'Colorado',
#   'Palau',
#   '631-070-2407',
#   'Lot improve product take crime fall quite list.',
#   '1967-09-12',
#   2058,
#   '2022-03-03 02:26:39.408658',
#   '2022-03-03 02:26:39.408661',
#   '168.157.29.21'),
#  (1654,
#   'David Griffin',
#   'ashley84@example.com',
#   '163 Reynolds Islands Suite 549\nRobertshaven, OH 30155',
#   'Port Ricardoland',
#   'Connecticut',
#   'Colombia',
#   '061.660.7464x87817',
#   'Community seek friend real training animal in great most daughter eight '
#   'season remain.',
#   '1967-09-12',
#   1164,
#   '2022-03-03 02:26:39.409449',
#   '2022-03-03 02:26:39.409454',
#   '53.176.6.180'),
#  (1655,
#   'Erin Hunter',
#   'adean@example.org',
#   '0978 Karen Key\nMirandaberg, IA 12990',
#   'Elizabethhaven',
#   'Nebraska',
#   'Pakistan',
#   '498.219.3803',
#   'School protect be might area discussion water become.',
#   '1967-09-12',
#   2175,
#   '2022-03-03 02:26:39.410184',
#   '2022-03-03 02:26:39.410188',
#   '22.44.187.240'),
#  (1656,
#   'Amy Reese',
#   'ecastillo@example.org',
#   '8723 Alexander Bridge\nFisherview, FL 40774',
#   'East Michael',
#   'New Mexico',
#   'Bulgaria',
#   '5377966005',
#   'Find nice as total growth official strategy interesting police which lay '
#   'where camera.',
#   '1967-09-12',
#   2172,
#   '2022-03-03 02:26:39.411204',
#   '2022-03-03 02:26:39.411211',
#   '13.195.132.193'),
#  (1657,
#   'Carolyn Herrera',
#   'uaguilar@example.net',
#   '44739 Jones Falls Apt. 698\nLeemouth, KS 87779',
#   'East Holly',
#   'Washington',
#   'French Polynesia',
#   '819.303.2207x125',
#   'Chance environmental movie fast break organization.',
#   '1967-09-12',
#   2185,
#   '2022-03-03 02:26:39.412175',
#   '2022-03-03 02:26:39.412180',
#   '187.126.66.127'),
#  (1658,
#   'Barbara Parker',
#   'timothyabbott@example.com',
#   '263 Mark Keys\nSanchezfort, IL 53368',
#   'Hensonland',
#   'Connecticut',
#   'Pitcairn Islands',
#   '(118)005-7080x216',
#   'Scientist sure change drop site teacher tell scientist society if trip '
#   'catch citizen.',
#   '1967-09-12',
#   1132,
#   '2022-03-03 02:26:39.413097',
#   '2022-03-03 02:26:39.413100',
#   '13.179.214.213'),
#  (1659,
#   'Dr. Brian Jones',
#   'medinatristan@example.org',
#   '3904 Weaver Parkways\nSouth Jenniferborough, PA 39159',
#   'North Justinshire',
#   'New Hampshire',
#   'Papua New Guinea',
#   '001-692-479-5266x2807',
#   'Simply yeah until herself best site.',
#   '1967-09-12',
#   1346,
#   '2022-03-03 02:26:39.414016',
#   '2022-03-03 02:26:39.414020',
#   '203.12.140.252'),
#  (1660,
#   'James Flores',
#   'jacobsmith@example.org',
#   'PSC 5590, Box 6583\nAPO AA 08799',
#   'South Patriciaville',
#   'West Virginia',
#   'Trinidad and Tobago',
#   '(219)351-9334x6782',
#   'Range tree tax hospital book positive page police office since later home '
#   'cover.',
#   '1967-09-12',
#   1287,
#   '2022-03-03 02:26:39.414709',
#   '2022-03-03 02:26:39.414712',
#   '98.34.76.33'),
#  (1661,
#   'Karen Griffin',
#   'andrew69@example.org',
#   '66076 Billy Ways\nAnnestad, MT 30414',
#   'Ravenburgh',
#   'Indiana',
#   'San Marino',
#   '399-320-6188',
#   'Big expect play model low herself capital data produce major market.',
#   '1967-09-12',
#   2329,
#   '2022-03-03 02:26:39.415441',
#   '2022-03-03 02:26:39.415445',
#   '27.58.75.73'),
#  (1662,
#   'William Smith',
#   'robinprice@example.net',
#   '1741 Laura Pass\nNorth Melissa, SD 17451',
#   'Port Natalie',
#   'Alabama',
#   'American Samoa',
#   '206-887-4880x207',
#   'Relate impact most choose energy fund sea power growth behind worker '
#   'audience.',
#   '1967-09-12',
#   1407,
#   '2022-03-03 02:26:39.416230',
#   '2022-03-03 02:26:39.416233',
#   '107.226.53.244'),
#  (1663,
#   'Joseph Mason',
#   'jake36@example.com',
#   '3076 Valenzuela Groves Suite 313\nJasonburgh, CT 39794',
#   'New Kimberlyborough',
#   'Nevada',
#   'Samoa',
#   '739-336-9529',
#   'Sometimes ability thus oil wonder the note beat.',
#   '1967-09-12',
#   2230,
#   '2022-03-03 02:26:39.416991',
#   '2022-03-03 02:26:39.416994',
#   '210.168.88.97'),
#  (1664,
#   'Adam Odom',
#   'wrightdavid@example.org',
#   '516 Ryan Hills\nRichardmouth, LA 82646',
#   'Matthewstad',
#   'Montana',
#   'Iceland',
#   '788.190.2305',
#   'Media opportunity read manager plan think compare sign father often three '
#   'oil.',
#   '1967-09-12',
#   2281,
#   '2022-03-03 02:26:39.417739',
#   '2022-03-03 02:26:39.417742',
#   '176.235.235.181'),
#  (1665,
#   'Stephen Taylor',
#   'linda94@example.org',
#   '128 Malone Brooks Apt. 614\nSinghville, WA 86952',
#   'Dakotastad',
#   'Iowa',
#   'Luxembourg',
#   '671-405-4245',
#   'We commercial stand although third involve next region back size.',
#   '1967-09-12',
#   2068,
#   '2022-03-03 02:26:39.418628',
#   '2022-03-03 02:26:39.418633',
#   '209.66.126.128'),
#  (1666,
#   'Tiffany Nelson',
#   'haynestaylor@example.net',
#   '8774 Todd Hollow Apt. 964\nEast Susantown, OK 55804',
#   'North Jakemouth',
#   'Maryland',
#   'Algeria',
#   '(884)674-3158x3084',
#   'Always final scene eye peace minute situation action.',
#   '1967-09-12',
#   1727,
#   '2022-03-03 02:26:39.419504',
#   '2022-03-03 02:26:39.419508',
#   '167.165.86.74'),
#  (1667,
#   'Henry Friedman',
#   'pamela42@example.net',
#   '579 Snyder Plain Suite 846\nGarciashire, MS 60003',
#   'Jacksonbury',
#   'Maine',
#   'United Arab Emirates',
#   '(863)097-6577',
#   'Coach thousand development nothing could measure worker type write.',
#   '1967-09-12',
#   1203,
#   '2022-03-03 02:26:39.420304',
#   '2022-03-03 02:26:39.420308',
#   '221.171.134.159'),
#  (1668,
#   'Brandy Copeland',
#   'jessica49@example.org',
#   '552 Michael Trace Suite 644\nTurnerhaven, IN 88358',
#   'South Amandahaven',
#   'North Dakota',
#   'Australia',
#   '(755)578-1776x784',
#   'Without hold realize despite one put foot each.',
#   '1967-09-12',
#   1841,
#   '2022-03-03 02:26:39.421067',
#   '2022-03-03 02:26:39.421070',
#   '91.16.189.133'),
#  (1669,
#   'Jeff Alvarez',
#   'jgreer@example.org',
#   '207 Smith Courts Apt. 416\nSouth Jennifer, UT 20182',
#   'South Douglas',
#   'New York',
#   'Cuba',
#   '727.060.0815x77395',
#   'Indeed technology forward away want example better occur consider look '
#   'most.',
#   '1967-09-12',
#   1789,
#   '2022-03-03 02:26:39.421842',
#   '2022-03-03 02:26:39.421846',
#   '18.90.206.59'),
#  (1670,
#   'Sarah Deleon',
#   'jduke@example.net',
#   '037 Barrett Trafficway Suite 812\nSouth Phyllisville, MT 21921',
#   'Lanemouth',
#   'South Carolina',
#   'Serbia',
#   '663.546.1015x78658',
#   'Recent political make dream be dinner.',
#   '1967-09-12',
#   1471,
#   '2022-03-03 02:26:39.422659',
#   '2022-03-03 02:26:39.422662',
#   '192.22.55.35'),
#  (1671,
#   'Jennifer Rodriguez',
#   'rcruz@example.net',
#   '64845 Debbie Ford Apt. 618\nSouth Michael, MS 00663',
#   'Brianshire',
#   'Delaware',
#   'Swaziland',
#   '001-586-655-6340x025',
#   'Out smile second source film wind.',
#   '1967-09-12',
#   2039,
#   '2022-03-03 02:26:39.423431',
#   '2022-03-03 02:26:39.423435',
#   '103.78.82.119'),
#  (1672,
#   'Jason Olsen',
#   'nrobinson@example.com',
#   'USNV Smith\nFPO AA 29399',
#   'West Crystal',
#   'Washington',
#   'Saint Helena',
#   '974.044.6346x9376',
#   'Green lead of alone financial stock present serve stop agent reveal under '
#   'risk.',
#   '1967-09-12',
#   1175,
#   '2022-03-03 02:26:39.424093',
#   '2022-03-03 02:26:39.424096',
#   '186.220.11.106'),
#  (1673,
#   'Cristina Campbell',
#   'tammywashington@example.org',
#   '43379 William Camp\nNew Kelly, TN 74431',
#   'Phelpsstad',
#   'New Mexico',
#   'Iraq',
#   '664-186-3461x562',
#   'Inside project wall although population culture president available prepare '
#   'authority skill.',
#   '1967-09-12',
#   1353,
#   '2022-03-03 02:26:39.424912',
#   '2022-03-03 02:26:39.424915',
#   '175.243.169.138'),
#  (1674,
#   'Brandon Stephenson',
#   'twarren@example.org',
#   '0443 Adams Points\nNew Johnchester, MA 11572',
#   'East Tamarastad',
#   'Nebraska',
#   'Guatemala',
#   '001-865-235-0628x66558',
#   'Effort long computer medical door tree they financial middle.',
#   '1967-09-12',
#   2111,
#   '2022-03-03 02:26:39.425675',
#   '2022-03-03 02:26:39.425678',
#   '4.255.170.5'),
#  (1675,
#   'Charles Hess',
#   'christina04@example.com',
#   '54631 Sexton Estate Apt. 574\nPaceville, LA 71291',
#   'Richardsonshire',
#   'Alaska',
#   'Philippines',
#   '7124378584',
#   'Risk contain not yeah month ten history agency fish.',
#   '1967-09-12',
#   1987,
#   '2022-03-03 02:26:39.426460',
#   '2022-03-03 02:26:39.426463',
#   '178.18.155.62'),
#  (1676,
#   'Daniel Cline',
#   'laura57@example.org',
#   '398 Hall Shoal\nNorth Kevin, NE 88247',
#   'Englishview',
#   'Wisconsin',
#   'Libyan Arab Jamahiriya',
#   '787-706-0918',
#   'Democrat home star fish reflect nearly animal college toward article hair '
#   'short human.',
#   '1967-09-12',
#   1342,
#   '2022-03-03 02:26:39.427212',
#   '2022-03-03 02:26:39.427215',
#   '116.219.145.252'),
#  (1677,
#   'John Boyer',
#   'petersonjoseph@example.com',
#   '118 John Valleys Suite 164\nLake Amy, RI 34013',
#   'Jamesport',
#   'Montana',
#   'Poland',
#   '775-500-4187',
#   'Certain direction article pretty data well.',
#   '1967-09-12',
#   1560,
#   '2022-03-03 02:26:39.427994',
#   '2022-03-03 02:26:39.427998',
#   '115.26.96.138'),
#  (1678,
#   'Bernard Cameron',
#   'stephen41@example.net',
#   '5513 Wagner Village Suite 890\nPort Paul, UT 38594',
#   'North Judithland',
#   'New Jersey',
#   'Mexico',
#   '001-295-449-9161x687',
#   'Red course material operation hear test since large.',
#   '1967-09-12',
#   1070,
#   '2022-03-03 02:26:39.428727',
#   '2022-03-03 02:26:39.428730',
#   '108.53.153.248'),
#  (1679,
#   'Angela Mullen',
#   'wardkristen@example.net',
#   '728 Mullins Shores Apt. 065\nJamesborough, WA 76889',
#   'Stephenview',
#   'Colorado',
#   'Greenland',
#   '238.525.1675',
#   'Debate little general vote well first bed course huge hotel situation voice '
#   'rest.',
#   '1967-09-12',
#   1920,
#   '2022-03-03 02:26:39.429544',
#   '2022-03-03 02:26:39.429548',
#   '17.107.201.240'),
#  (1680,
#   'Nancy Williams',
#   'gonzalezstephanie@example.net',
#   '69135 Martin Road\nKimberlymouth, WV 45979',
#   'North Bobby',
#   'Delaware',
#   'Bhutan',
#   '+1-441-378-5406x6257',
#   'Stay network yeah would own among.',
#   '1967-09-12',
#   1034,
#   '2022-03-03 02:26:39.430335',
#   '2022-03-03 02:26:39.430338',
#   '138.86.133.173'),
#  (1681,
#   'James Morgan',
#   'george97@example.net',
#   '904 Newman Cape\nCoffeyfort, SC 62700',
#   'New Gregoryfort',
#   'Maine',
#   'Niger',
#   '819.637.7560x407',
#   'Forget while minute section remember over writer its benefit effect should '
#   'fund offer.',
#   '1967-09-12',
#   1232,
#   '2022-03-03 02:26:39.431103',
#   '2022-03-03 02:26:39.431106',
#   '91.213.87.101'),
#  (1682,
#   'Deanna Cook',
#   'diana94@example.net',
#   '090 Perez Street\nWest Johntown, WY 20245',
#   'Rileyland',
#   'Virginia',
#   'Anguilla',
#   '698-060-5511',
#   'Top he just world Mrs pretty.',
#   '1967-09-12',
#   1947,
#   '2022-03-03 02:26:39.431853',
#   '2022-03-03 02:26:39.431856',
#   '69.152.97.90'),
#  (1683,
#   'Mr. Michael Gardner',
#   'yshort@example.com',
#   '324 Ashlee Mall\nJohnsonport, OR 65053',
#   'East Andrew',
#   'North Carolina',
#   'Kiribati',
#   '812.305.9851x01268',
#   'Huge everything both phone before after market require generation time '
#   'short culture.',
#   '1967-09-12',
#   1973,
#   '2022-03-03 02:26:39.432620',
#   '2022-03-03 02:26:39.432624',
#   '78.227.126.153'),
#  (1684,
#   'Sarah Patterson',
#   'michaellogan@example.net',
#   '6605 Brian Divide Suite 455\nNew Jorge, AL 32189',
#   'Hunterton',
#   'Virginia',
#   'Chile',
#   '5420870911',
#   'Trouble manage state especially difficult behavior be movie develop world '
#   'hear everything boy.',
#   '1967-09-12',
#   2435,
#   '2022-03-03 02:26:39.433444',
#   '2022-03-03 02:26:39.433447',
#   '205.112.197.8'),
#  (1685,
#   'Eric Powell',
#   'castrojoanne@example.com',
#   '61269 Jacqueline Station\nPort Rickystad, IL 30316',
#   'South Danielmouth',
#   'Nebraska',
#   'Hungary',
#   '291-255-0894x8032',
#   'Public billion agency half true oil catch magazine.',
#   '1967-09-12',
#   1683,
#   '2022-03-03 02:26:39.434239',
#   '2022-03-03 02:26:39.434242',
#   '212.195.27.37'),
#  (1686,
#   'April Webb',
#   'derricklynch@example.com',
#   '9236 Bradley Plains\nNorth Cindyfurt, FL 87957',
#   'Wolfton',
#   'Oregon',
#   'Fiji',
#   '190-419-1127x343',
#   'Fish might occur century to simply.',
#   '1967-09-12',
#   2153,
#   '2022-03-03 02:26:39.435109',
#   '2022-03-03 02:26:39.435114',
#   '150.102.141.87'),
#  (1687,
#   'Amy Murray',
#   'mvance@example.com',
#   '8648 Jeremiah Course\nOscarside, WV 35395',
#   'Annaton',
#   'Tennessee',
#   'French Southern Territories',
#   '652.983.1202x8640',
#   'Practice trip south may report interesting scientist attention fight might.',
#   '1967-09-12',
#   1122,
#   '2022-03-03 02:26:39.435876',
#   '2022-03-03 02:26:39.435880',
#   '195.99.12.68'),
#  (1688,
#   'Ashley Williams',
#   'cory98@example.net',
#   '06079 Perkins Manor Suite 017\nNortonhaven, SD 39893',
#   'Ramosfurt',
#   'West Virginia',
#   'Guam',
#   '+1-222-282-5071x59259',
#   'Owner hit bring what reduce go pass sister forget crime.',
#   '1967-09-12',
#   1583,
#   '2022-03-03 02:26:39.436673',
#   '2022-03-03 02:26:39.436676',
#   '139.63.216.32'),
#  (1689,
#   'Ms. Hailey Wagner DVM',
#   'juanhowell@example.com',
#   '35812 Michael Orchard\nPort Garyview, IL 69034',
#   'New Michael',
#   'Texas',
#   'Svalbard & Jan Mayen Islands',
#   '228.513.4261',
#   'Value detail civil budget know audience.',
#   '1967-09-12',
#   2454,
#   '2022-03-03 02:26:39.437478',
#   '2022-03-03 02:26:39.437482',
#   '192.42.95.25'),
#  (1690,
#   'Alicia Morrison',
#   'millsdawn@example.net',
#   '57956 Park Cliffs Suite 186\nSandersview, RI 61755',
#   'North Eric',
#   'West Virginia',
#   'Cayman Islands',
#   '3768197396',
#   'Particular term reveal baby very prepare picture pull theory behavior.',
#   '1967-09-12',
#   1075,
#   '2022-03-03 02:26:39.438355',
#   '2022-03-03 02:26:39.438359',
#   '210.26.152.32'),
#  (1691,
#   'Charles Clark',
#   'teresagardner@example.net',
#   '605 Joseph Circles\nSouth Michaelland, MS 82961',
#   'Port Jenniferhaven',
#   'Oregon',
#   'Honduras',
#   '(143)366-1659',
#   'Recognize interesting herself which edge face perhaps computer star '
#   'campaign most hospital.',
#   '1967-09-12',
#   1279,
#   '2022-03-03 02:26:39.439224',
#   '2022-03-03 02:26:39.439227',
#   '77.38.229.242'),
#  (1692,
#   'Erika Rogers',
#   'keithlloyd@example.org',
#   'USNV Stevens\nFPO AA 04546',
#   'Emmahaven',
#   'Michigan',
#   'Paraguay',
#   '944-537-8093x829',
#   'Among miss they open produce edge rule.',
#   '1967-09-12',
#   1521,
#   '2022-03-03 02:26:39.440007',
#   '2022-03-03 02:26:39.440011',
#   '14.91.2.15'),
#  (1693,
#   'Linda Sexton',
#   'jillbowman@example.com',
#   '588 Kim Views Apt. 234\nEddietown, MN 88670',
#   'East Ginafurt',
#   'South Carolina',
#   'Mozambique',
#   '001-536-072-4544',
#   'May movement Congress really oil range.',
#   '1967-09-12',
#   1177,
#   '2022-03-03 02:26:39.440992',
#   '2022-03-03 02:26:39.440996',
#   '26.116.202.74'),
#  (1694,
#   'Charles Howard',
#   'jaclynshaffer@example.com',
#   '059 Horton Harbors\nEdwardshire, NC 75152',
#   'West Jeffrey',
#   'Washington',
#   'Djibouti',
#   '199.462.2332',
#   'Artist real Congress north wind factor.',
#   '1967-09-12',
#   2449,
#   '2022-03-03 02:26:39.441956',
#   '2022-03-03 02:26:39.441961',
#   '136.95.177.217'),
#  (1695,
#   'Andrew Porter',
#   'regina16@example.com',
#   '07539 Victoria Mews Apt. 277\nNorth Heatherstad, IA 70882',
#   'New Lucaschester',
#   'West Virginia',
#   'Cape Verde',
#   '117.239.8168',
#   'Onto than on threat trial career partner small white on it guess debate.',
#   '1967-09-12',
#   1463,
#   '2022-03-03 02:26:39.442756',
#   '2022-03-03 02:26:39.442760',
#   '105.134.227.247'),
#  (1696,
#   'Joyce Rangel',
#   'john46@example.com',
#   '49508 Wright Way\nKirbyton, NM 35067',
#   'Tylerberg',
#   'Alabama',
#   'British Virgin Islands',
#   '001-892-152-9629x008',
#   'Decade serve contain focus blue theory check pull.',
#   '1967-09-12',
#   1719,
#   '2022-03-03 02:26:39.443907',
#   '2022-03-03 02:26:39.443912',
#   '79.248.189.35'),
#  (1697,
#   'Peter Carey',
#   'uryan@example.com',
#   '993 Bradley Estates Suite 416\nLake Laura, CA 28127',
#   'Russellland',
#   'West Virginia',
#   'Armenia',
#   '+1-294-233-8185x8732',
#   'People animal staff again base together effect baby off place Mr bank '
#   'service job.',
#   '1967-09-12',
#   2309,
#   '2022-03-03 02:26:39.444683',
#   '2022-03-03 02:26:39.444686',
#   '41.65.255.8'),
#  (1698,
#   'Patricia Collins',
#   'meganmejia@example.net',
#   '7928 James Spurs Suite 029\nMaldonadomouth, NM 83924',
#   'Coxhaven',
#   'Michigan',
#   'Iceland',
#   '207-776-6079',
#   'Few owner appear now board data.',
#   '1967-09-12',
#   1339,
#   '2022-03-03 02:26:39.445549',
#   '2022-03-03 02:26:39.445552',
#   '173.186.189.36'),
#  (1699,
#   'George Vasquez',
#   'uclark@example.org',
#   'PSC 4570, Box 2588\nAPO AA 02919',
#   'Saundersburgh',
#   'Massachusetts',
#   'Dominica',
#   '+1-864-042-6289x90731',
#   'Sign election various director bar difference option out.',
#   '1967-09-12',
#   2453,
#   '2022-03-03 02:26:39.446185',
#   '2022-03-03 02:26:39.446188',
#   '164.215.40.153'),
#  (1700,
#   'Chad Holloway',
#   'evansmelinda@example.com',
#   '6733 Joanna Court\nHigginsside, WV 35582',
#   'West Mackenzie',
#   'New Jersey',
#   'Seychelles',
#   '682.707.4740',
#   'Wide else subject career trip officer show strategy answer off final.',
#   '1967-09-12',
#   1264,
#   '2022-03-03 02:26:39.446995',
#   '2022-03-03 02:26:39.446998',
#   '161.215.209.156'),
#  (1701,
#   'Nancy Snyder',
#   'mayopaige@example.com',
#   '2532 Alexander Square Apt. 430\nPort Sharonmouth, FL 50263',
#   'Monroefurt',
#   'Kentucky',
#   'Sudan',
#   '6759726328',
#   'Paper through understand fund audience your exactly no nature food program '
#   'entire health.',
#   '1967-09-12',
#   1265,
#   '2022-03-03 02:26:39.447835',
#   '2022-03-03 02:26:39.447838',
#   '32.128.133.183'),
#  (1702,
#   'Charles Harris',
#   'grodriguez@example.com',
#   '60424 Katrina Mews\nLaurieland, WI 63053',
#   'East Danielleberg',
#   'Delaware',
#   'Cayman Islands',
#   '001-955-670-6628x63313',
#   'Specific west door enjoy challenge arm mention recognize.',
#   '1967-09-12',
#   1092,
#   '2022-03-03 02:26:39.448566',
#   '2022-03-03 02:26:39.448569',
#   '172.7.160.148'),
#  (1703,
#   'Courtney Diaz',
#   'michael68@example.com',
#   '10875 Randy Fork Apt. 386\nPort Kevinborough, AK 15482',
#   'Elizabethview',
#   'Maine',
#   'Brazil',
#   '+1-023-883-1487x626',
#   'Candidate whose us record Mr exist over human east project smile bed media.',
#   '1967-09-12',
#   1853,
#   '2022-03-03 02:26:39.449307',
#   '2022-03-03 02:26:39.449311',
#   '77.72.24.24'),
#  (1704,
#   'Terrance Gardner',
#   'wendy20@example.net',
#   '17918 Courtney Shore\nSouth Jonathanborough, ND 92393',
#   'Edwardsport',
#   'Oklahoma',
#   'China',
#   '001-445-171-3143x52456',
#   'Lead chair agree again strategy usually movement attorney.',
#   '1967-09-12',
#   1174,
#   '2022-03-03 02:26:39.450055',
#   '2022-03-03 02:26:39.450058',
#   '14.30.47.134'),
#  (1705,
#   'Abigail Jones',
#   'pgrant@example.com',
#   '11268 Jonathan Flat Suite 500\nAmandafort, MA 08114',
#   'New Daniel',
#   'Ohio',
#   'Bahamas',
#   '933-982-0426x320',
#   'Open air opportunity site station he hold thing teacher as real.',
#   '1967-09-12',
#   2419,
#   '2022-03-03 02:26:39.450787',
#   '2022-03-03 02:26:39.450790',
#   '209.60.129.173'),
#  (1706,
#   'Jennifer Johnson',
#   'dwhite@example.net',
#   '536 Reed Rest\nLake Michael, NV 45629',
#   'North Alicia',
#   'Virginia',
#   'Dominican Republic',
#   '001-438-893-3851x3677',
#   'It successful remain example fact Mr least.',
#   '1967-09-12',
#   1663,
#   '2022-03-03 02:26:39.451619',
#   '2022-03-03 02:26:39.451624',
#   '87.78.60.118'),
#  (1707,
#   'Mr. Richard Davis',
#   'dorothyhoward@example.org',
#   'USNS Rice\nFPO AA 35983',
#   'Douglasmouth',
#   'Utah',
#   'Turkey',
#   '+1-205-938-3609x0822',
#   'Despite reflect fine idea natural scientist woman far month near.',
#   '1967-09-12',
#   1742,
#   '2022-03-03 02:26:39.452365',
#   '2022-03-03 02:26:39.452368',
#   '198.181.185.251'),
#  (1708,
#   'John Gutierrez',
#   'dana95@example.net',
#   '9517 Walter Glens Suite 681\nNorth Jose, AR 31601',
#   'Melissaport',
#   'South Carolina',
#   'Philippines',
#   '001-208-070-6426x842',
#   'Network down sound happen spend before risk various wide human price.',
#   '1967-09-12',
#   1544,
#   '2022-03-03 02:26:39.453508',
#   '2022-03-03 02:26:39.453514',
#   '132.62.186.66'),
#  (1709,
#   'Jake Riley',
#   'bakerpatricia@example.org',
#   '6415 James Parks Apt. 357\nPort Jenniferfort, VA 34654',
#   'Martinezshire',
#   'Georgia',
#   'Norway',
#   '001-110-367-2617x2186',
#   'Bring keep page recently and win east least near decision mission '
#   'operation.',
#   '1967-09-12',
#   2289,
#   '2022-03-03 02:26:39.454472',
#   '2022-03-03 02:26:39.454476',
#   '130.168.154.7'),
#  (1710,
#   'Natalie Moore',
#   'jmartinez@example.net',
#   '462 Lopez Highway Suite 118\nMillerbury, AL 14012',
#   'Ericborough',
#   'North Dakota',
#   'Guyana',
#   '235.089.1947',
#   'Star knowledge nearly single machine yeah.',
#   '1967-09-12',
#   1543,
#   '2022-03-03 02:26:39.455382',
#   '2022-03-03 02:26:39.455386',
#   '211.209.102.193'),
#  (1711,
#   'Elizabeth Allen',
#   'gyang@example.com',
#   '46447 Taylor Cliff\nNew Katiebury, WA 70025',
#   'Billyland',
#   'Minnesota',
#   'United States Virgin Islands',
#   '108.773.9604',
#   'Modern traditional hear three rate stuff at government turn ahead woman '
#   'before.',
#   '1967-09-12',
#   2180,
#   '2022-03-03 02:26:39.456194',
#   '2022-03-03 02:26:39.456197',
#   '198.240.127.35'),
#  (1712,
#   'Matthew Smith',
#   'ann59@example.com',
#   'Unit 9047 Box 2020\nDPO AP 27749',
#   'East Alexander',
#   'Montana',
#   'Eritrea',
#   '(461)507-1780x35770',
#   'Forget smile degree already center girl.',
#   '1967-09-12',
#   2428,
#   '2022-03-03 02:26:39.456787',
#   '2022-03-03 02:26:39.456790',
#   '35.199.218.74'),
#  (1713,
#   'Angela Mcdowell',
#   'khankelly@example.org',
#   '35701 Sydney Manor Suite 187\nStephanieport, KS 78820',
#   'Mortonmouth',
#   'Massachusetts',
#   'Sweden',
#   '(043)436-0155x704',
#   'Suddenly information heavy end wish growth for we.',
#   '1967-09-12',
#   1948,
#   '2022-03-03 02:26:39.457634',
#   '2022-03-03 02:26:39.457637',
#   '37.232.164.106'),
#  (1714,
#   'Gloria Edwards',
#   'derek38@example.com',
#   '901 Kenneth Coves\nPort Jacob, IA 93260',
#   'Thompsonmouth',
#   'North Dakota',
#   'British Virgin Islands',
#   '0609430696',
#   'View concern beautiful official within voice yourself stock you them.',
#   '1967-09-12',
#   1826,
#   '2022-03-03 02:26:39.458392',
#   '2022-03-03 02:26:39.458396',
#   '125.9.179.184'),
#  (1715,
#   'Christine Wilson',
#   'fross@example.net',
#   '765 Martinez Keys Suite 197\nWest Joshua, FL 03621',
#   'Williamsfurt',
#   'Georgia',
#   'Jersey',
#   '(774)318-8594',
#   'Hour toward today owner fact that report choose rest crime event nothing '
#   'you.',
#   '1967-09-12',
#   1098,
#   '2022-03-03 02:26:39.459219',
#   '2022-03-03 02:26:39.459223',
#   '131.136.94.208'),
#  (1716,
#   'Mr. Bryan Fox',
#   'gabriel02@example.org',
#   '9450 Michelle Forges Suite 432\nKellyside, WI 27108',
#   'New Yolanda',
#   'New Hampshire',
#   'India',
#   '+1-400-614-7109',
#   'Budget follow tax imagine policy out not community alone.',
#   '1967-09-12',
#   2227,
#   '2022-03-03 02:26:39.459964',
#   '2022-03-03 02:26:39.459968',
#   '132.70.32.73'),
#  (1717,
#   'Taylor Duncan',
#   'dudleystephen@example.net',
#   '335 Alicia Drive\nPort Sheila, MT 43521',
#   'South Ianbury',
#   'Illinois',
#   'Tunisia',
#   '9492421615',
#   'Open else animal business enter work.',
#   '1967-09-12',
#   2489,
#   '2022-03-03 02:26:39.460738',
#   '2022-03-03 02:26:39.460741',
#   '45.62.109.84'),
#  (1718,
#   'Cameron Lopez',
#   'mooreanita@example.org',
#   '20442 Robin Mill Apt. 641\nEast Terranceshire, NC 54168',
#   'East Amanda',
#   'New Mexico',
#   'Saint Vincent and the Grenadines',
#   '001-524-630-1783x89295',
#   'Six bed oil sing whether easy lead myself population positive exist.',
#   '1967-09-12',
#   2350,
#   '2022-03-03 02:26:39.461666',
#   '2022-03-03 02:26:39.461671',
#   '56.52.58.230'),
#  (1719,
#   'Andrea Wright',
#   'zcarney@example.com',
#   '116 Theresa Circles Apt. 788\nKimberlyhaven, GA 87227',
#   'Allisontown',
#   'New Hampshire',
#   'Jersey',
#   '777-280-2467',
#   'Although nice seek throughout figure language guy.',
#   '1967-09-12',
#   1819,
#   '2022-03-03 02:26:39.462678',
#   '2022-03-03 02:26:39.462683',
#   '132.91.194.191'),
#  (1720,
#   'Joyce Howe',
#   'andrew20@example.net',
#   '7958 Castro Ville Apt. 096\nNew Thomasstad, AK 27057',
#   'North Teresaburgh',
#   'New Mexico',
#   'Cocos (Keeling) Islands',
#   '+1-806-414-1759',
#   'Impact others care much American yourself although education once culture '
#   'call improve also.',
#   '1967-09-12',
#   1954,
#   '2022-03-03 02:26:39.463499',
#   '2022-03-03 02:26:39.463503',
#   '105.57.21.25'),
#  (1721,
#   'Sarah Willis',
#   'jessica41@example.org',
#   '364 Strickland Avenue Suite 436\nNew Davidmouth, SD 80424',
#   'North Tarafurt',
#   'Maryland',
#   'Iraq',
#   '+1-328-410-5823x4675',
#   'Town another age result window about trial team choice wife two source '
#   'audience.',
#   '1967-09-12',
#   2110,
#   '2022-03-03 02:26:39.464285',
#   '2022-03-03 02:26:39.464288',
#   '162.157.35.62'),
#  (1722,
#   'Jennifer Bradley PhD',
#   'william08@example.net',
#   '159 David Trail Apt. 456\nJessicaburgh, KY 60007',
#   'Scottborough',
#   'New Jersey',
#   'Netherlands',
#   '158-939-6460x07601',
#   'Including prove election good piece century.',
#   '1967-09-12',
#   1479,
#   '2022-03-03 02:26:39.465033',
#   '2022-03-03 02:26:39.465037',
#   '150.30.246.101'),
#  (1723,
#   'Martha Rodriguez',
#   'bradleywilliam@example.net',
#   '3188 Elizabeth Stravenue\nJamestown, MA 60979',
#   'North Michaelfort',
#   'Vermont',
#   'Somalia',
#   '532.393.4180x6425',
#   'Price stand wife effect authority establish movie.',
#   '1967-09-12',
#   1469,
#   '2022-03-03 02:26:39.465840',
#   '2022-03-03 02:26:39.465844',
#   '48.61.8.100'),
#  (1724,
#   'George Galvan',
#   'shirley73@example.com',
#   '085 Pearson Via\nTerriland, MN 88284',
#   'Payneside',
#   'Hawaii',
#   'Jersey',
#   '999.690.0002',
#   'Simply movie many cup speech determine soldier everyone.',
#   '1967-09-12',
#   2037,
#   '2022-03-03 02:26:39.466586',
#   '2022-03-03 02:26:39.466589',
#   '39.72.133.133'),
#  (1725,
#   'Jeffrey Smith',
#   'robertcarpenter@example.org',
#   '06134 Sheri Oval\nSouth Juanshire, KY 03921',
#   'Port Sandrabury',
#   'Hawaii',
#   'Micronesia',
#   '(911)211-5194',
#   'Buy billion out everyone explain number wear focus break attack throw.',
#   '1967-09-12',
#   2060,
#   '2022-03-03 02:26:39.467401',
#   '2022-03-03 02:26:39.467405',
#   '217.0.78.211'),
#  (1726,
#   'Kristine Hinton',
#   'rcollins@example.org',
#   '3241 Simmons Glens Apt. 965\nBirdshire, CT 59848',
#   'Matthewchester',
#   'Indiana',
#   'Bhutan',
#   '855.656.5289x450',
#   'House create end natural evidence benefit.',
#   '1967-09-12',
#   1191,
#   '2022-03-03 02:26:39.468213',
#   '2022-03-03 02:26:39.468218',
#   '85.172.155.240'),
#  (1727,
#   'Kevin Turner',
#   'hwilliams@example.net',
#   'PSC 7645, Box 0635\nAPO AA 31872',
#   'Angelafort',
#   'South Dakota',
#   'Wallis and Futuna',
#   '(183)818-3853x83640',
#   'Him their out letter civil particular seat great over go.',
#   '1967-09-12',
#   1300,
#   '2022-03-03 02:26:39.468828',
#   '2022-03-03 02:26:39.468832',
#   '65.191.111.161'),
#  (1728,
#   'David Barber',
#   'mejiamaria@example.net',
#   '24447 Martinez Row\nJamesmouth, CT 27700',
#   'Nguyenview',
#   'Wisconsin',
#   'Lesotho',
#   '692.274.0608x456',
#   'Information soldier into recently action whether end fast check.',
#   '1967-09-12',
#   1785,
#   '2022-03-03 02:26:39.469674',
#   '2022-03-03 02:26:39.469677',
#   '152.208.76.0'),
#  (1729,
#   'Anthony Herrera',
#   'donna42@example.org',
#   '807 Isaac Inlet Suite 678\nSouth Jasonview, MT 76948',
#   'East Justinside',
#   'Hawaii',
#   'Trinidad and Tobago',
#   '332.509.4307',
#   'Soon foreign something message town quality.',
#   '1967-09-12',
#   1518,
#   '2022-03-03 02:26:39.470411',
#   '2022-03-03 02:26:39.470414',
#   '99.212.11.41'),
#  (1730,
#   'Heather Sanchez',
#   'feliciawatts@example.org',
#   '56809 Angela Drive\nEast Valeriemouth, LA 00799',
#   'Carterstad',
#   'Colorado',
#   'Bulgaria',
#   '409-614-6531',
#   'Pick sell condition record hard we every today from book.',
#   '1967-09-12',
#   1414,
#   '2022-03-03 02:26:39.471244',
#   '2022-03-03 02:26:39.471248',
#   '154.132.42.225'),
#  (1731,
#   'Brian Bryant',
#   'ballluis@example.org',
#   '4926 Kirsten Springs\nPort Andrew, LA 30325',
#   'Port Nathanton',
#   'Michigan',
#   'Sierra Leone',
#   '+1-617-896-3478',
#   'Reflect debate yourself talk rule fish fire owner power gun those street.',
#   '1967-09-12',
#   1462,
#   '2022-03-03 02:26:39.472051',
#   '2022-03-03 02:26:39.472055',
#   '74.159.222.199'),
#  (1732,
#   'Patricia Cooper',
#   'landerson@example.org',
#   '2937 Erin Locks Apt. 709\nChristyborough, CO 48658',
#   'Stricklandfort',
#   'Alabama',
#   'United States Minor Outlying Islands',
#   '+1-831-717-0288x46956',
#   'Need response mean everybody window never physical serious.',
#   '1967-09-12',
#   1846,
#   '2022-03-03 02:26:39.472847',
#   '2022-03-03 02:26:39.472851',
#   '131.33.39.179'),
#  (1733,
#   'Jennifer Clark',
#   'loweryjohn@example.org',
#   '0957 Adam Locks\nGregview, ND 65578',
#   'West Jacob',
#   'Michigan',
#   'Cook Islands',
#   '001-561-273-5751x0808',
#   'Like see east ever sometimes blue audience.',
#   '1967-09-12',
#   1210,
#   '2022-03-03 02:26:39.473630',
#   '2022-03-03 02:26:39.473633',
#   '164.77.255.237'),
#  (1734,
#   'Amanda Williamson',
#   'nancyalvarez@example.net',
#   '3979 Johnson Street Suite 246\nLake Kyletown, WY 79250',
#   'Christophermouth',
#   'Alabama',
#   'Montenegro',
#   '130-402-0959x53210',
#   'Society wind sport a husband left finish word general security effect '
#   'parent.',
#   '1967-09-12',
#   2210,
#   '2022-03-03 02:26:39.474523',
#   '2022-03-03 02:26:39.474527',
#   '217.138.56.152'),
#  (1735,
#   'Vanessa Lane',
#   'williamsstephanie@example.org',
#   '658 Andrea Creek\nJoshuaberg, ME 51543',
#   'Moorefort',
#   'Virginia',
#   'French Guiana',
#   '297.511.7685x988',
#   'Hold pass direction cell large imagine boy real call fear difficult '
#   'perhaps.',
#   '1967-09-12',
#   1819,
#   '2022-03-03 02:26:39.475373',
#   '2022-03-03 02:26:39.475377',
#   '140.37.127.156'),
#  (1736,
#   'Michael Smith',
#   'josephjones@example.org',
#   '5426 Lee Bypass Apt. 045\nHenryton, PA 50562',
#   'West Johnnyshire',
#   'Hawaii',
#   'Vanuatu',
#   '357-238-0941x922',
#   'Which next none of color three student traditional this action indicate '
#   'soon.',
#   '1967-09-12',
#   1434,
#   '2022-03-03 02:26:39.476248',
#   '2022-03-03 02:26:39.476252',
#   '83.70.192.87'),
#  (1737,
#   'Kristin Bentley',
#   'joel72@example.org',
#   '1720 Jeffrey Island\nNew Jamesside, ME 09167',
#   'North Ericstad',
#   'Wyoming',
#   'Lesotho',
#   '0580227355',
#   'System station pay dream soldier set seek claim nor at real.',
#   '1967-09-12',
#   2189,
#   '2022-03-03 02:26:39.476997',
#   '2022-03-03 02:26:39.477001',
#   '159.15.81.145'),
#  (1738,
#   'Melissa Reese',
#   'owashington@example.org',
#   '5121 Suzanne Mall Suite 083\nStevenland, MT 32983',
#   'East Gregory',
#   'Arizona',
#   'Bolivia',
#   '(159)692-0479x5045',
#   'Example suddenly give system charge carry where for street policy us '
#   'personal now.',
#   '1967-09-12',
#   1744,
#   '2022-03-03 02:26:39.477745',
#   '2022-03-03 02:26:39.477748',
#   '110.33.203.223'),
#  (1739,
#   'Timothy Sanchez',
#   'michael57@example.org',
#   '975 Robert Mountains\nSouth Jessica, KY 81554',
#   'Lake Sarahview',
#   'West Virginia',
#   'Jamaica',
#   '087-475-4765',
#   'Sign Democrat suffer travel result meeting choice.',
#   '1967-09-12',
#   1649,
#   '2022-03-03 02:26:39.478459',
#   '2022-03-03 02:26:39.478463',
#   '93.75.95.42'),
#  (1740,
#   'Diane Alexander',
#   'thomasjones@example.net',
#   '09811 Morgan Garden Suite 814\nReynoldston, TX 92020',
#   'Pamelatown',
#   'Wisconsin',
#   'Jamaica',
#   '(736)337-8971x150',
#   'Without color full week recognize improve on his.',
#   '1967-09-12',
#   1773,
#   '2022-03-03 02:26:39.479333',
#   '2022-03-03 02:26:39.479336',
#   '139.180.15.157'),
#  (1741,
#   'Kevin Larson',
#   'cassandrasmith@example.net',
#   '799 Williams Court\nSouth Linda, NM 01908',
#   'Tranfurt',
#   'North Carolina',
#   'Trinidad and Tobago',
#   '001-117-800-7534',
#   'Thing better into employee kind benefit leader same account soldier.',
#   '1967-09-12',
#   2064,
#   '2022-03-03 02:26:39.480411',
#   '2022-03-03 02:26:39.480418',
#   '151.36.85.176'),
#  (1742,
#   'Antonio Schroeder',
#   'nyoung@example.net',
#   '6394 Lambert Manor Apt. 964\nKatelynbury, NY 48964',
#   'North Patricia',
#   'Texas',
#   'Philippines',
#   '001-691-647-0996x36528',
#   'Pull great answer year lot behind much treat western offer a.',
#   '1967-09-12',
#   2451,
#   '2022-03-03 02:26:39.481315',
#   '2022-03-03 02:26:39.481319',
#   '190.173.233.101'),
#  (1743,
#   'Mary Stanley',
#   'longjustin@example.org',
#   '3154 Page View\nPort Debra, WI 07437',
#   'Mullenchester',
#   'Vermont',
#   'Eritrea',
#   '(731)565-6911x8591',
#   'Field east forward guess why yes.',
#   '1967-09-12',
#   1014,
#   '2022-03-03 02:26:39.482223',
#   '2022-03-03 02:26:39.482227',
#   '52.12.238.82'),
#  (1744,
#   'Curtis Parker DVM',
#   'xwoodard@example.com',
#   '0091 Monica Mount Apt. 856\nWest Andrewshire, NM 07904',
#   'West Shirley',
#   'Maryland',
#   'Faroe Islands',
#   '001-129-726-6799x98258',
#   'Same worker arm fund night order decade man every energy trip.',
#   '1967-09-12',
#   1551,
#   '2022-03-03 02:26:39.483070',
#   '2022-03-03 02:26:39.483073',
#   '185.98.158.34'),
#  (1745,
#   'Bryan Kim',
#   'amandaalvarez@example.com',
#   '2148 Riley Landing Suite 372\nWardport, WV 98186',
#   'New Nicole',
#   'Alabama',
#   'South Georgia and the South Sandwich Islands',
#   '+1-849-182-2934x16412',
#   'President rule put why hot despite action mission factor others social.',
#   '1967-09-12',
#   1822,
#   '2022-03-03 02:26:39.484219',
#   '2022-03-03 02:26:39.484225',
#   '24.103.168.62'),
#  (1746,
#   'Andrea Harris',
#   'barbaraward@example.org',
#   '93623 Boone Flats\nWrightborough, IA 21613',
#   'Lewisfort',
#   'Colorado',
#   'Bermuda',
#   '001-825-609-2229x92879',
#   'Design his cultural trouble stock smile interest natural party.',
#   '1967-09-12',
#   2465,
#   '2022-03-03 02:26:39.485213',
#   '2022-03-03 02:26:39.485217',
#   '112.73.8.99'),
#  (1747,
#   'Lisa Perez',
#   'cummingswesley@example.net',
#   '0676 Garza Points Suite 828\nNew Heidishire, CT 23752',
#   'West Kristen',
#   'Virginia',
#   'Poland',
#   '001-250-207-9793x692',
#   'Physical truth sense no step wall check style religious half.',
#   '1967-09-12',
#   1260,
#   '2022-03-03 02:26:39.486111',
#   '2022-03-03 02:26:39.486115',
#   '6.75.76.168'),
#  (1748,
#   'Natasha Neal',
#   'curtis10@example.net',
#   '2463 Woodward Grove Suite 155\nJosefurt, OH 81990',
#   'Morganhaven',
#   'New Mexico',
#   'Iceland',
#   '6044858160',
#   'Fly house fact pull large seven phone financial too us popular.',
#   '1967-09-12',
#   1763,
#   '2022-03-03 02:26:39.486906',
#   '2022-03-03 02:26:39.486910',
#   '170.15.230.132'),
#  (1749,
#   'Lauren Davis',
#   'serranoamber@example.net',
#   '798 Jones Loaf\nDouglasshire, WA 85708',
#   'East Robert',
#   'California',
#   'Kuwait',
#   '3884611671',
#   'Some open ground huge its ability improve appear least rate wrong last.',
#   '1967-09-12',
#   2052,
#   '2022-03-03 02:26:39.487744',
#   '2022-03-03 02:26:39.487747',
#   '144.172.106.92'),
#  (1750,
#   'Jacob Booker',
#   'lisa16@example.com',
#   '24709 Faulkner Hill Suite 984\nLake Carlview, HI 95142',
#   'South Kathy',
#   'Nebraska',
#   'Montenegro',
#   '446-944-9319',
#   'Life view by oil laugh suddenly.',
#   '1967-09-12',
#   1810,
#   '2022-03-03 02:26:39.488525',
#   '2022-03-03 02:26:39.488528',
#   '28.79.19.150'),
#  (1751,
#   'Gary Moore',
#   'daniel05@example.com',
#   '01137 Lara Course Apt. 471\nNew Robert, SC 08177',
#   'Alanview',
#   'Arizona',
#   'Samoa',
#   '(009)850-6092x26513',
#   'Win finish trip environment possible risk.',
#   '1967-09-12',
#   2348,
#   '2022-03-03 02:26:39.489296',
#   '2022-03-03 02:26:39.489299',
#   '60.227.91.125'),
#  (1752,
#   'William Robinson',
#   'courtneystewart@example.com',
#   '2553 Brown Garden Suite 541\nSouth John, KY 27677',
#   'Port Stephaniechester',
#   'Missouri',
#   'Vietnam',
#   '(889)086-6803x1544',
#   'Class our sell money southern provide body any card remember toward fast '
#   'visit.',
#   '1967-09-12',
#   1897,
#   '2022-03-03 02:26:39.490274',
#   '2022-03-03 02:26:39.490279',
#   '186.10.135.220'),
#  (1753,
#   'Christopher Bell',
#   'kdonovan@example.com',
#   '0141 Melody Island Apt. 654\nGarciabury, AK 53184',
#   'Whiteshire',
#   'Nebraska',
#   'Suriname',
#   '605-829-6417x7982',
#   'Travel half eight street instead long receive under major or side.',
#   '1967-09-12',
#   2148,
#   '2022-03-03 02:26:39.491212',
#   '2022-03-03 02:26:39.491217',
#   '22.245.112.209'),
#  (1754,
#   'Charles Lopez',
#   'chloe04@example.com',
#   '74666 Carpenter Hill Suite 240\nRodriguezhaven, NJ 01338',
#   'New Rachel',
#   'New Hampshire',
#   'Syrian Arab Republic',
#   '(947)131-4232',
#   'Political chair world participant garden you lot level day knowledge '
#   'serious design window very.',
#   '1967-09-12',
#   2194,
#   '2022-03-03 02:26:39.492022',
#   '2022-03-03 02:26:39.492026',
#   '139.96.173.100'),
#  (1755,
#   'Cody Mclaughlin',
#   'jose74@example.com',
#   'Unit 0149 Box 9431\nDPO AP 37091',
#   'Dixonborough',
#   'Montana',
#   'Holy See (Vatican City State)',
#   '001-134-452-7658x967',
#   'Try bill how keep blue help seek meet interest.',
#   '1967-09-12',
#   2312,
#   '2022-03-03 02:26:39.492611',
#   '2022-03-03 02:26:39.492614',
#   '121.238.228.170'),
#  (1756,
#   'John Boone',
#   'laurie22@example.com',
#   '902 Cervantes Square\nAprilton, PA 46591',
#   'Frankstad',
#   'Georgia',
#   'Djibouti',
#   '001-654-071-5599x407',
#   'Commercial generation tonight bring I quite.',
#   '1967-09-12',
#   2273,
#   '2022-03-03 02:26:39.493356',
#   '2022-03-03 02:26:39.493360',
#   '5.169.185.79'),
#  (1757,
#   'Grant Huffman',
#   'pherrera@example.net',
#   '651 Dominique Isle\nWest Faith, CT 72270',
#   'North Charles',
#   'New York',
#   'France',
#   '(860)041-4665',
#   'Position dream human food lawyer data what term performance.',
#   '1967-09-12',
#   1488,
#   '2022-03-03 02:26:39.494089',
#   '2022-03-03 02:26:39.494093',
#   '200.214.118.234'),
#  (1758,
#   'Christopher Figueroa',
#   'uhall@example.com',
#   '401 Kathleen Trace Suite 261\nEast Monicachester, SC 71347',
#   'Port Thomas',
#   'Washington',
#   'Brunei Darussalam',
#   '311.232.8426',
#   'Shoulder source current wear none side prevent deal best low single major '
#   'south.',
#   '1967-09-12',
#   1181,
#   '2022-03-03 02:26:39.494855',
#   '2022-03-03 02:26:39.494858',
#   '142.20.150.136'),
#  (1759,
#   'Dennis Patel',
#   'lewisamanda@example.com',
#   '9390 Carlson Hollow Suite 496\nBlackhaven, MO 37260',
#   'Lake Janemouth',
#   'California',
#   'Palestinian Territory',
#   '419.560.5768x1205',
#   'Admit find throughout recognize Mr traditional think three.',
#   '1967-09-12',
#   1160,
#   '2022-03-03 02:26:39.495688',
#   '2022-03-03 02:26:39.495691',
#   '12.196.87.222'),
#  (1760,
#   'Jessica Hawkins',
#   'emily10@example.org',
#   '854 Joshua Court\nAlvarezport, IN 92419',
#   'East Savannah',
#   'Louisiana',
#   'Jordan',
#   '465.879.4210',
#   'Resource tough everybody which everything strong size fear reduce.',
#   '1967-09-12',
#   1946,
#   '2022-03-03 02:26:39.496423',
#   '2022-03-03 02:26:39.496426',
#   '160.226.175.183'),
#  (1761,
#   'Emily Boyd',
#   'michael37@example.org',
#   '3377 Jones Trafficway Suite 612\nPort Tammy, AR 12032',
#   'South Amberton',
#   'Colorado',
#   'Italy',
#   '+1-300-575-6756',
#   'Station end officer attack road American sign so.',
#   '1967-09-12',
#   2478,
#   '2022-03-03 02:26:39.497182',
#   '2022-03-03 02:26:39.497186',
#   '181.120.55.8'),
#  (1762,
#   'David Santiago',
#   'millermichelle@example.org',
#   '49843 Howard Path Suite 813\nNguyenfort, VA 68007',
#   'Melissashire',
#   'Connecticut',
#   'Heard Island and McDonald Islands',
#   '(716)028-5239x882',
#   'Close responsibility Democrat him design reflect example until shoulder '
#   'move project.',
#   '1967-09-12',
#   2361,
#   '2022-03-03 02:26:39.498553',
#   '2022-03-03 02:26:39.498561',
#   '147.47.42.195'),
#  (1763,
#   'Kari Price',
#   'xhernandez@example.net',
#   '88929 Derrick Junction\nNorth Tracy, ME 04788',
#   'Lake Robinside',
#   'California',
#   'Bouvet Island (Bouvetoya)',
#   '111.031.8612x5196',
#   'Another able current meeting see service.',
#   '1967-09-12',
#   1989,
#   '2022-03-03 02:26:39.499917',
#   '2022-03-03 02:26:39.499924',
#   '158.84.218.37'),
#  (1764,
#   'Mary Moreno',
#   'richard87@example.org',
#   '20470 Ellis Springs\nWest George, NY 14508',
#   'West Williamport',
#   'Kansas',
#   'Suriname',
#   '001-626-694-9975x43915',
#   'Draw option current near husband tree model approach might join once rather '
#   'fight.',
#   '1967-09-12',
#   1352,
#   '2022-03-03 02:26:39.501258',
#   '2022-03-03 02:26:39.501264',
#   '67.163.125.124'),
#  (1765,
#   'Brittany Andrews',
#   'harroyo@example.com',
#   '6186 Noble Square Apt. 210\nRhondamouth, GA 92766',
#   'East Katelynbury',
#   'Ohio',
#   'Azerbaijan',
#   '024-675-0100x778',
#   'Effort fish significant news certainly matter young majority morning east.',
#   '1967-09-12',
#   1666,
#   '2022-03-03 02:26:39.502658',
#   '2022-03-03 02:26:39.502664',
#   '168.159.37.137'),
#  (1766,
#   'Taylor Martin',
#   'phillip85@example.com',
#   '505 Hansen Crest Suite 213\nWest Josephmouth, TN 31190',
#   'Cesarbury',
#   'Virginia',
#   'Saint Lucia',
#   '0664477758',
#   'Form heart research total responsibility campaign save dog office majority '
#   'how note those.',
#   '1967-09-12',
#   1612,
#   '2022-03-03 02:26:39.504010',
#   '2022-03-03 02:26:39.504016',
#   '129.98.231.232'),
#  (1767,
#   'Elizabeth Brown',
#   'johnmiller@example.com',
#   '54158 Michael Fields Suite 645\nCarolineport, CT 73953',
#   'North Kenneth',
#   'Ohio',
#   'Cook Islands',
#   '851-289-8229',
#   'Better agent success product deal kind above who.',
#   '1967-09-12',
#   1407,
#   '2022-03-03 02:26:39.505395',
#   '2022-03-03 02:26:39.505401',
#   '171.7.210.82'),
#  (1768,
#   'Anthony Owens',
#   'brianballard@example.org',
#   'USS Johnson\nFPO AA 25760',
#   'South Megan',
#   'New York',
#   'Micronesia',
#   '563-160-9048x9029',
#   'Require lay include claim either police notice heavy win me whom message.',
#   '1967-09-12',
#   1078,
#   '2022-03-03 02:26:39.506654',
#   '2022-03-03 02:26:39.506660',
#   '133.122.80.7'),
#  (1769,
#   'Heather Meyer',
#   'allison47@example.net',
#   '0894 Sanchez Groves\nLake Jessica, VA 92850',
#   'North James',
#   'Oklahoma',
#   'Yemen',
#   '1140984334',
#   'Moment actually or that admit call power wrong bank final.',
#   '1967-09-12',
#   1738,
#   '2022-03-03 02:26:39.507996',
#   '2022-03-03 02:26:39.508002',
#   '196.198.216.221'),
#  (1770,
#   'Laura Grant',
#   'ryanamanda@example.net',
#   '3679 Hayes Station Suite 732\nLeemouth, IN 08256',
#   'Amymouth',
#   'Arizona',
#   'Bolivia',
#   '+1-835-893-9297',
#   'Some how authority let whom reduce but store.',
#   '1967-09-12',
#   2336,
#   '2022-03-03 02:26:39.509505',
#   '2022-03-03 02:26:39.509511',
#   '78.37.0.73'),
#  (1771,
#   'Danielle Rose',
#   'michael52@example.net',
#   '763 Banks Road Suite 589\nDonnaport, IA 46448',
#   'Lake Kimberly',
#   'Colorado',
#   'Mali',
#   '001-278-464-8078x96773',
#   'College floor by deal little lose exactly health teach others market.',
#   '1967-09-12',
#   2003,
#   '2022-03-03 02:26:39.510892',
#   '2022-03-03 02:26:39.510898',
#   '14.17.248.91'),
#  (1772,
#   'Judith Holt',
#   'jacob58@example.net',
#   '78819 Cynthia Locks Apt. 467\nPort Sarah, DE 64577',
#   'Bryanside',
#   'West Virginia',
#   'Togo',
#   '(063)903-2984',
#   'Once lot lot argue people personal defense of Democrat leader door.',
#   '1967-09-12',
#   1275,
#   '2022-03-03 02:26:39.512178',
#   '2022-03-03 02:26:39.512184',
#   '115.121.159.31'),
#  (1773,
#   'Shawn Phillips MD',
#   'nicholas51@example.com',
#   '89195 Greg Key Apt. 387\nSummersside, OH 70451',
#   'South Tyler',
#   'Pennsylvania',
#   'Gibraltar',
#   '+1-098-641-0434x8865',
#   'Grow piece mention seven sister appear news short much test adult.',
#   '1967-09-12',
#   1587,
#   '2022-03-03 02:26:39.513549',
#   '2022-03-03 02:26:39.513554',
#   '218.161.247.32'),
#  (1774,
#   'Anthony Moore',
#   'jessicapatterson@example.net',
#   '323 King Island Suite 476\nMyersborough, NC 46260',
#   'Thomasshire',
#   'New Hampshire',
#   'United States of America',
#   '7056937993',
#   'Right collection social expect ago car new.',
#   '1967-09-12',
#   1261,
#   '2022-03-03 02:26:39.515093',
#   '2022-03-03 02:26:39.515098',
#   '63.123.176.195'),
#  (1775,
#   'Kathryn Pearson',
#   'pamela87@example.net',
#   '921 Kristina Village Apt. 160\nFoleyview, DE 52438',
#   'Masseymouth',
#   'Missouri',
#   'Suriname',
#   '3591454964',
#   'Service onto other professor particularly across cultural character hot.',
#   '1967-09-12',
#   1379,
#   '2022-03-03 02:26:39.516458',
#   '2022-03-03 02:26:39.516464',
#   '128.111.238.150'),
#  (1776,
#   'Maria Stevenson',
#   'jerry99@example.com',
#   '0157 Kelly Lake Apt. 351\nJamesburgh, KS 41638',
#   'Rodriguezbury',
#   'Indiana',
#   'Dominican Republic',
#   '902-894-6876x142',
#   'Statement much public affect high seven human.',
#   '1967-09-12',
#   2471,
#   '2022-03-03 02:26:39.517740',
#   '2022-03-03 02:26:39.517745',
#   '74.162.136.58'),
#  (1777,
#   'Kevin Olson',
#   'hwolf@example.net',
#   '167 Espinoza Extensions Suite 283\nKrystalmouth, NH 33620',
#   'Steventon',
#   'Alabama',
#   'Zimbabwe',
#   '803-856-6451x85704',
#   'Staff wind some cup scene interest must issue or market own article able.',
#   '1967-09-12',
#   2460,
#   '2022-03-03 02:26:39.518578',
#   '2022-03-03 02:26:39.518582',
#   '168.1.253.101'),
#  (1778,
#   'Natasha Williams',
#   'umyers@example.org',
#   '23728 Lee Stream Apt. 002\nFranklinstad, MA 70467',
#   'Anthonymouth',
#   'Georgia',
#   'Morocco',
#   '(906)888-3530',
#   'Television make day author word better say down avoid learn.',
#   '1967-09-12',
#   1621,
#   '2022-03-03 02:26:39.519445',
#   '2022-03-03 02:26:39.519449',
#   '129.109.35.184'),
#  (1779,
#   'Philip Travis',
#   'barbaraharmon@example.net',
#   '9170 Nichols Trail\nKaylafurt, WA 57090',
#   'New Robert',
#   'Ohio',
#   'Northern Mariana Islands',
#   '001-497-681-8854x066',
#   'At later development light natural financial involve safe police phone '
#   'should.',
#   '1967-09-12',
#   1695,
#   '2022-03-03 02:26:39.520317',
#   '2022-03-03 02:26:39.520321',
#   '30.179.92.181'),
#  (1780,
#   'Angela Miller',
#   'eileenowens@example.org',
#   '93050 Donna Inlet Apt. 234\nDanielside, VT 63310',
#   'North Danielle',
#   'Rhode Island',
#   'Comoros',
#   '(659)304-5508',
#   'Between require record military ten study police.',
#   '1967-09-12',
#   1336,
#   '2022-03-03 02:26:39.521168',
#   '2022-03-03 02:26:39.521172',
#   '112.130.146.69'),
#  (1781,
#   'Kimberly Gibbs',
#   'richardsonelizabeth@example.com',
#   '083 Yates Forks Apt. 094\nWest Ryanchester, TN 55627',
#   'Ginahaven',
#   'North Dakota',
#   'Western Sahara',
#   '+1-958-472-6627x639',
#   'Performance science politics amount assume computer reveal stuff at focus '
#   'song article address.',
#   '1967-09-12',
#   1712,
#   '2022-03-03 02:26:39.522068',
#   '2022-03-03 02:26:39.522073',
#   '167.121.78.174'),
#  (1782,
#   'Erin Figueroa MD',
#   'longmelissa@example.org',
#   '886 Russell Island Apt. 961\nNorth Patriciaborough, WA 13032',
#   'West Austinborough',
#   'Nebraska',
#   'Honduras',
#   '132-607-3257',
#   'Thing debate nice scene security after source like.',
#   '1967-09-12',
#   2022,
#   '2022-03-03 02:26:39.523000',
#   '2022-03-03 02:26:39.523005',
#   '67.150.69.108'),
#  (1783,
#   'Sergio Moon',
#   'sanchezrobert@example.org',
#   '35658 Lisa Lock Suite 141\nFernandezberg, PA 45545',
#   'North Ashley',
#   'Wisconsin',
#   'New Zealand',
#   '001-761-512-8984x68932',
#   'Coach perform pass accept lot increase politics.',
#   '1967-09-12',
#   1002,
#   '2022-03-03 02:26:39.523888',
#   '2022-03-03 02:26:39.523892',
#   '118.91.96.197'),
#  (1784,
#   'Carmen Mitchell',
#   'corey86@example.com',
# ...
#   'that.',
#   '1967-09-12',
#   1250,
#   '2022-03-03 02:26:39.671260',
#   '2022-03-03 02:26:39.671263',
#   '214.77.81.8'),
#  (1956,
#   'Jordan Brown',
#   'operez@example.net',
#   '16078 Sanchez Mill\nThomasstad, ME 11927',
#   'Jesusmouth',
#   'Nevada',
#   'Maldives',
#   '(131)741-8824',
#   'Result town within believe may together glass hour friend.',
#   '1967-09-12',
#   2211,
#   '2022-03-03 02:26:39.672050',
#   '2022-03-03 02:26:39.672054',
#   '105.16.153.220'),
#  (1957,
#   'Adam Sparks',
#   'danielsandrew@example.net',
#   '124 David Extension\nTroymouth, TN 28156',
#   'East William',
#   'Nevada',
#   'Germany',
#   '(121)254-2911',
#   'Space sometimes as truth cover rather both visit ready plant ever indicate '
#   'enough.',
#   '1967-09-12',
#   1672,
#   '2022-03-03 02:26:39.672859',
#   '2022-03-03 02:26:39.672864',
#   '191.56.80.154'),
#  (1958,
#   'Kathryn Cook',
#   'jake41@example.net',
#   '724 Wright Isle Suite 748\nPort Donaldville, UT 11738',
#   'North Jasmineport',
#   'Tennessee',
#   'Cocos (Keeling) Islands',
#   '600.445.8939x41367',
#   'Develop he consider tend too staff yourself.',
#   '1967-09-12',
#   1378,
#   '2022-03-03 02:26:39.673643',
#   '2022-03-03 02:26:39.673646',
#   '117.184.204.198'),
#  (1959,
#   'Kenneth Lopez PhD',
#   'alvarezmichael@example.com',
#   '7837 Gregory Drive\nCarlyton, MI 63257',
#   'New Tonyland',
#   'Illinois',
#   'Qatar',
#   '816.352.9175x1512',
#   'Middle short collection foreign nearly significant agency.',
#   '1967-09-12',
#   1191,
#   '2022-03-03 02:26:39.674455',
#   '2022-03-03 02:26:39.674458',
#   '64.4.12.164'),
#  (1960,
#   'Mr. Antonio Sharp',
#   'david01@example.org',
#   '589 Brown Mountain\nNew Sandy, DC 57235',
#   'Sabrinaville',
#   'West Virginia',
#   'Zambia',
#   '+1-457-898-2131x935',
#   'Lay difficult between hand information career.',
#   '1967-09-12',
#   1764,
#   '2022-03-03 02:26:39.675191',
#   '2022-03-03 02:26:39.675194',
#   '4.196.117.108'),
#  (1961,
#   'Brittany Cole',
#   'wwright@example.net',
#   '1758 Salazar Greens\nWest Mallorybury, IA 07301',
#   'Kennethtown',
#   'Pennsylvania',
#   'Zimbabwe',
#   '(044)751-6934',
#   'Imagine receive risk trade know glass daughter dark else.',
#   '1967-09-12',
#   1642,
#   '2022-03-03 02:26:39.675998',
#   '2022-03-03 02:26:39.676002',
#   '174.35.10.219'),
#  (1962,
#   'Jimmy Allen DVM',
#   'tjones@example.net',
#   '651 Harry Land Apt. 704\nSouth Mitchellstad, DC 06127',
#   'Samanthamouth',
#   'Wisconsin',
#   'Lesotho',
#   '298-166-6869x015',
#   'Be city study artist entire coach agreement officer success never.',
#   '1967-09-12',
#   1708,
#   '2022-03-03 02:26:39.676768',
#   '2022-03-03 02:26:39.676771',
#   '101.232.235.120'),
#  (1963,
#   'Danielle Dillon',
#   'campbellcurtis@example.org',
#   '6386 Angela Isle\nValenciatown, GA 71203',
#   'Jonesshire',
#   'Texas',
#   'Christmas Island',
#   '798-498-6641x67257',
#   'Property certainly rule body left staff appear short.',
#   '1967-09-12',
#   1416,
#   '2022-03-03 02:26:39.677618',
#   '2022-03-03 02:26:39.677622',
#   '80.198.9.154'),
#  (1964,
#   'Trevor Cooper',
#   'sarahstafford@example.org',
#   '21510 Andrea Drive Suite 578\nCoreyville, DC 86242',
#   'Sanchezfurt',
#   'Nevada',
#   'Tanzania',
#   '669.334.2801x3760',
#   'Away system her later suggest seat suddenly see listen.',
#   '1967-09-12',
#   1494,
#   '2022-03-03 02:26:39.678445',
#   '2022-03-03 02:26:39.678448',
#   '55.219.18.0'),
#  (1965,
#   'Mr. Kevin Ayala',
#   'wendycox@example.org',
#   '660 Boyer Squares\nDarlenebury, AK 57940',
#   'New Kevinton',
#   'Arizona',
#   'Western Sahara',
#   '841.693.1288',
#   'Officer human religious side easy budget.',
#   '1967-09-12',
#   1739,
#   '2022-03-03 02:26:39.679296',
#   '2022-03-03 02:26:39.679300',
#   '223.29.85.4'),
#  (1966,
#   'Keith Anderson',
#   'pdavis@example.com',
#   '18464 Carter Fort Suite 568\nNorth Ronniemouth, ID 05774',
#   'North Denise',
#   'Hawaii',
#   'Antarctica (the territory South of 60 deg S)',
#   '+1-351-118-5675x25695',
#   'Fall choose event whatever popular choose some drive next way individual.',
#   '1967-09-12',
#   2288,
#   '2022-03-03 02:26:39.680117',
#   '2022-03-03 02:26:39.680120',
#   '158.9.163.22'),
#  (1967,
#   'Mr. John Robinson',
#   'christianrobinson@example.org',
#   '184 Powers Island Apt. 222\nSouth Michael, ID 98601',
#   'Mejiahaven',
#   'Wisconsin',
#   'Pitcairn Islands',
#   '446.011.3222',
#   'Near yard leg line never institution wait smile up training.',
#   '1967-09-12',
#   2259,
#   '2022-03-03 02:26:39.680984',
#   '2022-03-03 02:26:39.680988',
#   '75.37.127.192'),
#  (1968,
#   'Kristen Ellis',
#   'jessicabecker@example.net',
#   '3823 Young Crest\nWest Jenniferstad, WV 05823',
#   'Christopherberg',
#   'Georgia',
#   'Jamaica',
#   '5692220019',
#   'Himself which arm wall daughter mind.',
#   '1967-09-12',
#   1425,
#   '2022-03-03 02:26:39.681806',
#   '2022-03-03 02:26:39.681810',
#   '9.194.233.136'),
#  (1969,
#   'David Reeves',
#   'kramerrichard@example.net',
#   '8270 Robinson Mount Suite 961\nGarrisonberg, KY 19712',
#   'North Andrew',
#   'Maryland',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '327-725-5482',
#   'Any opportunity none memory key more by movement like successful drop film.',
#   '1967-09-12',
#   1411,
#   '2022-03-03 02:26:39.682662',
#   '2022-03-03 02:26:39.682665',
#   '117.31.93.49'),
#  (1970,
#   'Nathan Trujillo',
#   'sandra60@example.net',
#   '86557 David Drives Suite 417\nLake Kristamouth, WY 06583',
#   'Georgemouth',
#   'Oregon',
#   'Belize',
#   '001-591-240-1228x00311',
#   'Business specific much among specific inside agency doctor.',
#   '1967-09-12',
#   1809,
#   '2022-03-03 02:26:39.683428',
#   '2022-03-03 02:26:39.683433',
#   '44.152.156.253'),
#  (1971,
#   'Crystal Diaz',
#   'calderondesiree@example.com',
#   '342 Ryan Stream\nShelbyburgh, HI 02188',
#   'New Amy',
#   'Alaska',
#   'Sri Lanka',
#   '007.846.5168',
#   'Mention money the modern key scene his note fish edge.',
#   '1967-09-12',
#   1211,
#   '2022-03-03 02:26:39.684223',
#   '2022-03-03 02:26:39.684226',
#   '54.136.27.147'),
#  (1972,
#   'Stephanie Reid',
#   'kcarter@example.com',
#   'Unit 9493 Box 2237\nDPO AE 90558',
#   'Andrewberg',
#   'Montana',
#   'Jamaica',
#   '(185)262-3810',
#   'Learn because office huge although well work.',
#   '1967-09-12',
#   1196,
#   '2022-03-03 02:26:39.684850',
#   '2022-03-03 02:26:39.684854',
#   '195.106.2.243'),
#  (1973,
#   'Jennifer Reese',
#   'edonovan@example.net',
#   '468 Matthew Junction\nPort Josephmouth, AZ 64807',
#   'Shermanstad',
#   'Missouri',
#   'Faroe Islands',
#   '(693)811-7257',
#   'Health politics deep some same Congress not walk eat necessary.',
#   '1967-09-12',
#   1780,
#   '2022-03-03 02:26:39.685591',
#   '2022-03-03 02:26:39.685594',
#   '22.155.198.243'),
#  (1974,
#   'Andrew Medina',
#   'scottlinda@example.org',
#   '639 Dixon Station Apt. 840\nDanielletown, MS 14590',
#   'North Grantside',
#   'New Mexico',
#   'Nauru',
#   '+1-272-411-9343',
#   'Behind difficult early thing official leave simply soldier mention.',
#   '1967-09-12',
#   1203,
#   '2022-03-03 02:26:39.686408',
#   '2022-03-03 02:26:39.686411',
#   '210.80.86.0'),
#  (1975,
#   'Kristen Walker',
#   'ramosmichael@example.org',
#   '5410 Walker Crossroad\nLambertshire, VA 12516',
#   'East Calebshire',
#   'Utah',
#   'Lebanon',
#   '+1-069-383-6486x529',
#   'Level knowledge in big bar option.',
#   '1967-09-12',
#   1196,
#   '2022-03-03 02:26:39.687242',
#   '2022-03-03 02:26:39.687245',
#   '110.47.203.133'),
#  (1976,
#   'John Lee',
#   'taylor44@example.org',
#   '308 Erickson Fork\nLake Jeremyborough, VT 86993',
#   'Stevenfort',
#   'Utah',
#   'Niue',
#   '669-482-9637x404',
#   'South prove trade law your strong create beautiful fall.',
#   '1967-09-12',
#   1009,
#   '2022-03-03 02:26:39.688000',
#   '2022-03-03 02:26:39.688003',
#   '73.241.85.10'),
#  (1977,
#   'Kevin Gonzalez',
#   'youngmichael@example.net',
#   '678 Corey Camp Apt. 550\nEast Howardton, VA 90147',
#   'Gabriellefort',
#   'West Virginia',
#   "Lao People's Democratic Republic",
#   '001-407-919-9756x64500',
#   'Or heart section practice any magazine skin size day at oil thus.',
#   '1967-09-12',
#   1503,
#   '2022-03-03 02:26:39.688813',
#   '2022-03-03 02:26:39.688817',
#   '77.159.180.56'),
#  (1978,
#   'David Williams',
#   'amanda53@example.com',
#   '53198 Christopher Track Apt. 434\nLesliehaven, DC 16087',
#   'Johnstad',
#   'Nebraska',
#   'Guam',
#   '7678102125',
#   'Research value gun trial manager wall direction.',
#   '1967-09-12',
#   2293,
#   '2022-03-03 02:26:39.689515',
#   '2022-03-03 02:26:39.689518',
#   '104.2.151.161'),
#  (1979,
#   'Amy Ballard',
#   'tracymendez@example.com',
#   '9793 Jennifer Mount Apt. 809\nKelleyborough, NV 75762',
#   'Charleshaven',
#   'Nebraska',
#   'Isle of Man',
#   '421.324.1988',
#   'Kid arrive attack call chance draw reason feeling let task court training '
#   'oil laugh.',
#   '1967-09-12',
#   1759,
#   '2022-03-03 02:26:39.690320',
#   '2022-03-03 02:26:39.690323',
#   '5.103.1.179'),
#  (1980,
#   'Todd Michael',
#   'susan38@example.org',
#   '605 Amanda Lock Apt. 777\nBrendaburgh, ND 28913',
#   'Christophershire',
#   'South Dakota',
#   'South Africa',
#   '+1-654-157-0017',
#   'Worry friend anything thank seat course then.',
#   '1967-09-12',
#   2287,
#   '2022-03-03 02:26:39.691030',
#   '2022-03-03 02:26:39.691033',
#   '194.12.98.0'),
#  (1981,
#   'Mike Wilson',
#   'nicholsdale@example.net',
#   'Unit 7971 Box 5569\nDPO AA 16156',
#   'Moranstad',
#   'Oregon',
#   'Mexico',
#   '+1-256-022-6312x352',
#   'Theory style marriage play listen to.',
#   '1967-09-12',
#   1136,
#   '2022-03-03 02:26:39.691686',
#   '2022-03-03 02:26:39.691689',
#   '91.220.19.114'),
#  (1982,
#   'Donald Chan',
#   'jessica95@example.org',
#   '0658 John Islands\nSheliatown, ME 08966',
#   'New Victoria',
#   'Texas',
#   'Swaziland',
#   '+1-765-555-9443x3957',
#   'Fill civil design give should big worry election federal.',
#   '1967-09-12',
#   1991,
#   '2022-03-03 02:26:39.692418',
#   '2022-03-03 02:26:39.692421',
#   '199.244.8.58'),
#  (1983,
#   'Shawn Gilbert',
#   'kingjulie@example.com',
#   'USNS Barr\nFPO AA 40216',
#   'Villatown',
#   'Connecticut',
#   'French Polynesia',
#   '877-106-1687x068',
#   'Difficult performance cover wonder order often report describe tax give '
#   'scientist edge father.',
#   '1967-09-12',
#   1560,
#   '2022-03-03 02:26:39.693139',
#   '2022-03-03 02:26:39.693142',
#   '213.229.18.214'),
#  (1984,
#   'Ronald Greene',
#   'gloria93@example.com',
#   '87341 Jonathan Club\nSmithport, GA 49816',
#   'South Tiffany',
#   'Maryland',
#   'Bangladesh',
#   '+1-377-547-2238x169',
#   'Owner eight assume agent boy third car data human claim believe clearly '
#   'may.',
#   '1967-09-12',
#   2351,
#   '2022-03-03 02:26:39.693870',
#   '2022-03-03 02:26:39.693873',
#   '179.47.147.121'),
#  (1985,
#   'Jason Smith',
#   'thompsonjohn@example.com',
#   '84267 Saunders Street Suite 474\nWendychester, ND 86583',
#   'Lake Lindamouth',
#   'Washington',
#   'Cuba',
#   '815.384.2387x80143',
#   'Notice remain off certain stuff price defense shoulder help democratic '
#   'network same.',
#   '1967-09-12',
#   1642,
#   '2022-03-03 02:26:39.694682',
#   '2022-03-03 02:26:39.694685',
#   '125.220.29.78'),
#  (1986,
#   'Christopher Salazar',
#   'chanson@example.org',
#   '055 John Meadows\nOlsenburgh, AZ 64114',
#   'North Joshuafurt',
#   'Indiana',
#   'Niger',
#   '001-849-648-2801x605',
#   'Turn team about responsibility gas cold production positive available '
#   'physical contain state.',
#   '1967-09-12',
#   2079,
#   '2022-03-03 02:26:39.695444',
#   '2022-03-03 02:26:39.695448',
#   '118.23.196.103'),
#  (1987,
#   'Shannon Bailey',
#   'hpatton@example.com',
#   '29651 Michael Shores\nZimmermanhaven, TN 22626',
#   'Andreberg',
#   'Kentucky',
#   'British Virgin Islands',
#   '(394)146-4910x7568',
#   'Her guess treat manage coach writer suffer especially end might great.',
#   '1967-09-12',
#   1547,
#   '2022-03-03 02:26:39.696203',
#   '2022-03-03 02:26:39.696206',
#   '158.181.222.52'),
#  (1988,
#   'Philip Anderson',
#   'scottsimmons@example.org',
#   '021 Linda Prairie\nPollardberg, PA 70783',
#   'Lake John',
#   'Alaska',
#   'Reunion',
#   '1011726503',
#   'Language plant you head especially present national.',
#   '1967-09-12',
#   1199,
#   '2022-03-03 02:26:39.697016',
#   '2022-03-03 02:26:39.697020',
#   '182.149.185.182'),
#  (1989,
#   'Kimberly Bell',
#   'juliebrown@example.org',
#   '26692 Brian Ridge\nNew Christina, VT 72178',
#   'Stephensonport',
#   'Kansas',
#   'Thailand',
#   '1333261606',
#   'Knowledge speech product fund religious turn generation start nothing I '
#   'reality skin.',
#   '1967-09-12',
#   1098,
#   '2022-03-03 02:26:39.697823',
#   '2022-03-03 02:26:39.697826',
#   '172.199.26.133'),
#  (1990,
#   'Mia Ponce',
#   'omiller@example.net',
#   '9999 Kelly Ridge\nBarnestown, NH 60088',
#   'East Joseph',
#   'Tennessee',
#   'Algeria',
#   '910-340-6047x564',
#   'Tree loss lose current thought ball so several experience so political walk '
#   'development.',
#   '1967-09-12',
#   1727,
#   '2022-03-03 02:26:39.698595',
#   '2022-03-03 02:26:39.698598',
#   '60.107.128.179'),
#  (1991,
#   'Jenny Middleton',
#   'gibbsjavier@example.com',
#   '19577 Stephen Springs\nJohnsonmouth, SD 79597',
#   'Port Bryan',
#   'Arkansas',
#   'Finland',
#   '063-280-4116',
#   'Toward claim establish environment learn respond success similar mind.',
#   '1967-09-12',
#   1447,
#   '2022-03-03 02:26:39.699392',
#   '2022-03-03 02:26:39.699396',
#   '103.181.231.68'),
#  (1992,
#   'Angela Cook',
#   'ejohnson@example.com',
#   '99282 Johnson Prairie\nKennedymouth, IL 85465',
#   'New Brendastad',
#   'New Jersey',
#   'Moldova',
#   '780-955-0942x8468',
#   'Short travel conference yeah establish vote identify.',
#   '1967-09-12',
#   1825,
#   '2022-03-03 02:26:39.700167',
#   '2022-03-03 02:26:39.700170',
#   '196.4.113.100'),
#  (1993,
#   'Christopher Perry',
#   'qwest@example.com',
#   'Unit 1346 Box 6313\nDPO AP 34820',
#   'Robersonborough',
#   'Idaho',
#   'Paraguay',
#   '273.441.2545',
#   'Herself treatment crime believe course call.',
#   '1967-09-12',
#   1586,
#   '2022-03-03 02:26:39.700757',
#   '2022-03-03 02:26:39.700760',
#   '204.55.46.2'),
#  (1994,
#   'Kenneth Castro',
#   'andrewfernandez@example.com',
#   'Unit 6388 Box 8314\nDPO AA 54832',
#   'Cabreraton',
#   'Delaware',
#   'Kazakhstan',
#   '001-858-215-6578',
#   'Take entire let bag dinner suffer within either.',
#   '1967-09-12',
#   1089,
#   '2022-03-03 02:26:39.701416',
#   '2022-03-03 02:26:39.701419',
#   '157.248.89.53'),
#  (1995,
#   'Jeffrey Murphy',
#   'psanchez@example.org',
#   '10242 Mallory Highway Suite 209\nVeronicaburgh, HI 15090',
#   'Lake Brandon',
#   'Maryland',
#   'Peru',
#   '809.961.1646x373',
#   'Matter partner government series movement last consumer behavior whose oil '
#   'skill determine happy.',
#   '1967-09-12',
#   1154,
#   '2022-03-03 02:26:39.702163',
#   '2022-03-03 02:26:39.702166',
#   '18.85.204.37'),
#  (1996,
#   'Frank Barnes',
#   'ortegalaurie@example.org',
#   '33345 Guzman Ports\nLechester, CT 64291',
#   'New Sierra',
#   'New Mexico',
#   'Ecuador',
#   '(682)135-6153x932',
#   'Type everyone culture fall appear station near clear establish item.',
#   '1967-09-12',
#   2089,
#   '2022-03-03 02:26:39.703017',
#   '2022-03-03 02:26:39.703020',
#   '102.233.203.143'),
#  (1997,
#   'Joshua Cisneros',
#   'efrey@example.net',
#   'Unit 6914 Box 3008\nDPO AP 53602',
#   'Sarahborough',
#   'Louisiana',
#   'Kyrgyz Republic',
#   '001-916-786-3807',
#   'Many benefit hour receive prevent piece mouth happy bar issue animal.',
#   '1967-09-12',
#   1843,
#   '2022-03-03 02:26:39.703597',
#   '2022-03-03 02:26:39.703600',
#   '99.3.155.120'),
#  (1998,
#   'Christopher Hartman DDS',
#   'monicaadams@example.com',
#   '5763 Richard Forge Apt. 876\nReynoldsburgh, TN 51408',
#   'New Patrickmouth',
#   'Oregon',
#   'Cook Islands',
#   '6599786046',
#   'Might fact age size theory offer very past case change test each.',
#   '1967-09-12',
#   2473,
#   '2022-03-03 02:26:39.704436',
#   '2022-03-03 02:26:39.704439',
#   '16.15.199.90'),
#  (1999,
#   'Jasmine Salinas',
#   'morrissharon@example.com',
#   '0718 Caleb Junction Apt. 425\nNew Dakotaton, CA 33392',
#   'Richardfurt',
#   'Alaska',
#   'Zimbabwe',
#   '249.324.2657x1924',
#   'Far nation understand travel effect care art American party.',
#   '1967-09-12',
#   2466,
#   '2022-03-03 02:26:39.705236',
#   '2022-03-03 02:26:39.705239',
#   '29.104.188.65'),
#  (2000,
#   'Danielle Silva',
#   'travisalvarez@example.net',
#   '6517 Brown Drive\nWilsonview, MA 89028',
#   'South Melissa',
#   'Alabama',
#   'Cook Islands',
#   '0341328249',
#   'Task event truth image stage west such her.',
#   '1967-09-12',
#   1467,
#   '2022-03-03 02:26:39.706067',
#   '2022-03-03 02:26:39.706070',
#   '130.122.176.205')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT name, heatmap FROM people 
                            WHERE heatmap > 1500
                            LIMIT 20"""

myCursor.execute( selectStatement )
results = myCursor.fetchall()
print(results)
# Out:
# [('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101), ('Bryan Turner', 2101)]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
